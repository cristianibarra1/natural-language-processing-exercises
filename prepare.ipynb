# %% [markdown]
# # Exercises
#
# The end result of this exercise should be a file named prepare.py that defines the requested functions.
#
# In this exercise we will be defining some functions to prepare textual data. These functions should apply equally well to both the codeup blog articles and the news articles that were previously acquired.
#
# #### 1)Define a function named basic_clean. It should take in a string and apply some basic text cleaning to it:
#
# >Lowercase everything
#
# >Normalize unicode characters
#
# >Replace anything that is not a letter, number, whitespace or a single quote.
#
# #### *(2)*Define a function named tokenize. It should take in a string and tokenize all the words in the string.
#
# #### 3)Define a function named stem. It should accept some text and return the text after applying stemming to all the words.
#
# #### 4)Define a function named lemmatize. It should accept some text and return the text after applying lemmatization to each word.
#
# #### 5)Define a function named remove_stopwords. It should accept some text and return the text after removing all the stopwords.
#
# >This function should define two optional parameters, extra_words and exclude_words. These parameters should define any additional stop words to include, and any words that we don't want to remove.
#
# #### 6)Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe news_df.
#
# #### 7)Make another dataframe for the Codeup blog posts. Name the dataframe codeup_df.
#
# #### 8)For each dataframe, produce the following columns:
#
# >title to hold the title
#
# >original to hold the original article/post content
#
# >clean to hold the normalized and tokenized original with the stopwords removed.
#
# >stemmed to hold the stemmed version of the cleaned data.
#
# >lemmatized to hold the lemmatized version of the cleaned data.
#
# #### 9)Ask yourself:
#
# >If your corpus is 493KB, would you prefer to use stemmed or lemmatized text?
#
# >If your corpus is 25MB, would you prefer to use stemmed or lemmatized text?
#
# >If your corpus is 200TB of text and you're charged by the megabyte for your hosted computational resources, would
# you prefer to use stemmed or lemmatized text?

# %%
import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import pandas as pd
import acquire

# %%
# nltk.download('all')

# %%
df=acquire.codeup_blogs()
df.head()
# Out:
#                                                title date_published  \
# 0               Is a Career in Tech Recession-Proof?   Aug 12, 2022
# 1  Codeup Honored as SABJ Diversity and Inclusion...    Oct 7, 2022
# 2            How Can I Finance My Career Transition?   Sep 29, 2022
# 3          Tips for Women Beginning a Career in Tech   Sep 23, 2022
# 4   2022 SABJ C-Suite Award Winner: Stephen Noteboom    Sep 9, 2022
#
#                                              content
# 0  \n\n\n\n\n\nGiven the current economic climate...
# 1  \nCodeup has been named the 2022 Diversity and...
# 2  \nDeciding to transition into a tech career is...
# 3  \nCodeup strongly values diversity, and inclus...
# 4  \nCodeup’s Chief Operating Officer, Stephen No...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           6 non-null      object
#  1   date_published  6 non-null      object
#  2   content         6 non-null      object
# dtypes: object(3)
# memory usage: 272.0+ bytes

# %%
business_df=acquire.cut_from_one('business')
business_df.head()
# Out:
#                                                title  \
# 0  Infosys' attrition drops to 27.1%, net employe...
# 1  We do not support dual employment: Infosys on ...
# 2  Musk sells $1 million worth of 'Burnt Hair' pe...
# 3  Mukesh Ambani visits Kedarnath & Badrinath shr...
# 4  IKEA lays off 10,000 employees after halting R...
#
#                                              content  category
# 0  Infosys on Thursday reported a 1.3% QoQ drop i...  business
# 1  Infosys CEO Salil Parekh spoke on the moonligh...  business
# 2  The world's richest person Elon Musk earned a ...  business
# 3  Reliance Industries Chairman Mukesh Ambani on ...  business
# 4  Swedish ready-to-assemble furniture retailer I...  business

# %%
business_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     25 non-null     object
#  1   content   25 non-null     object
#  2   category  25 non-null     object
# dtypes: object(3)
# memory usage: 728.0+ bytes

# %%
business_df_2=business_df.copy()

# %% [markdown]
# # 1)Define a function named basic_clean. It should take in a string and apply some basic text cleaning to it:
#
# >Lowercase everything
#
# >Normalize unicode characters
#
# >Replace anything that is not a letter, number, whitespace or a single quote.

# %%
#Define a function to clean text data
def basic_clean(string):
    
    string = string.lower()
    
    string = unicodedata.normalize('NFKD', string).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    
    string = re.sub(r"[^a-z0-9\s']", '', string)
    
    return string

# %%
business_df['basic_clean']=business_df['content'].apply(basic_clean)
business_df.head()
# Out:
#                                                title  \
# 0  Infosys' attrition drops to 27.1%, net employe...
# 1  We do not support dual employment: Infosys on ...
# 2  Musk sells $1 million worth of 'Burnt Hair' pe...
# 3  Mukesh Ambani visits Kedarnath & Badrinath shr...
# 4  IKEA lays off 10,000 employees after halting R...
#
#                                              content  category  \
# 0  Infosys on Thursday reported a 1.3% QoQ drop i...  business
# 1  Infosys CEO Salil Parekh spoke on the moonligh...  business
# 2  The world's richest person Elon Musk earned a ...  business
# 3  Reliance Industries Chairman Mukesh Ambani on ...  business
# 4  Swedish ready-to-assemble furniture retailer I...  business
#
#                                          basic_clean
# 0  infosys on thursday reported a 13 qoq drop in ...
# 1  infosys ceo salil parekh spoke on the moonligh...
# 2  the world's richest person elon musk earned a ...
# 3  reliance industries chairman mukesh ambani on ...
# 4  swedish readytoassemble furniture retailer ike...

# %% [markdown]
# # *(2)*Define a function named tokenize. It should take in a string and tokenize all the words in the string.

# %%
def tokenize(string):
    
    tokenizer = ToktokTokenizer()
    
    return tokenizer.tokenize(string, return_str=True)

# %%
business_df['tokenize']=business_df['content'].apply(tokenize)
business_df.head()
# Out:
#                                                title  \
# 0  Infosys' attrition drops to 27.1%, net employe...
# 1  We do not support dual employment: Infosys on ...
# 2  Musk sells $1 million worth of 'Burnt Hair' pe...
# 3  Mukesh Ambani visits Kedarnath & Badrinath shr...
# 4  IKEA lays off 10,000 employees after halting R...
#
#                                              content  category  \
# 0  Infosys on Thursday reported a 1.3% QoQ drop i...  business
# 1  Infosys CEO Salil Parekh spoke on the moonligh...  business
# 2  The world's richest person Elon Musk earned a ...  business
# 3  Reliance Industries Chairman Mukesh Ambani on ...  business
# 4  Swedish ready-to-assemble furniture retailer I...  business
#
#                                          basic_clean  \
# 0  infosys on thursday reported a 13 qoq drop in ...
# 1  infosys ceo salil parekh spoke on the moonligh...
# 2  the world's richest person elon musk earned a ...
# 3  reliance industries chairman mukesh ambani on ...
# 4  swedish readytoassemble furniture retailer ike...
#
#                                             tokenize
# 0  Infosys on Thursday reported a 1.3 % QoQ drop ...
# 1  Infosys CEO Salil Parekh spoke on the moonligh...
# 2  The world ' s richest person Elon Musk earned ...
# 3  Reliance Industries Chairman Mukesh Ambani on ...
# 4  Swedish ready-to-assemble furniture retailer I...

# %% [markdown]
# # 3)Define a function named stem. It should accept some text and return the text after applying stemming to all the words.

# %%
def stem(string):
    
    ps = nltk.porter.PorterStemmer()
    
    stems = [ps.stem(word) for word in string.split()]
    
    stemmed_string = ' '.join(stems)
    
    return stemmed_string

# %%
business_df['stem']=business_df['content'].apply(stem)
business_df.head()
# Out:
#                                                title  \
# 0  Infosys' attrition drops to 27.1%, net employe...
# 1  We do not support dual employment: Infosys on ...
# 2  Musk sells $1 million worth of 'Burnt Hair' pe...
# 3  Mukesh Ambani visits Kedarnath & Badrinath shr...
# 4  IKEA lays off 10,000 employees after halting R...
#
#                                              content  category  \
# 0  Infosys on Thursday reported a 1.3% QoQ drop i...  business
# 1  Infosys CEO Salil Parekh spoke on the moonligh...  business
# 2  The world's richest person Elon Musk earned a ...  business
# 3  Reliance Industries Chairman Mukesh Ambani on ...  business
# 4  Swedish ready-to-assemble furniture retailer I...  business
#
#                                          basic_clean  \
# 0  infosys on thursday reported a 13 qoq drop in ...
# 1  infosys ceo salil parekh spoke on the moonligh...
# 2  the world's richest person elon musk earned a ...
# 3  reliance industries chairman mukesh ambani on ...
# 4  swedish readytoassemble furniture retailer ike...
#
#                                             tokenize  \
# 0  Infosys on Thursday reported a 1.3 % QoQ drop ...
# 1  Infosys CEO Salil Parekh spoke on the moonligh...
# 2  The world ' s richest person Elon Musk earned ...
# 3  Reliance Industries Chairman Mukesh Ambani on ...
# 4  Swedish ready-to-assemble furniture retailer I...
#
#                                                 stem
# 0  infosi on thursday report a 1.3% qoq drop in i...
# 1  infosi ceo salil parekh spoke on the moonlight...
# 2  the world' richest person elon musk earn a mil...
# 3  relianc industri chairman mukesh ambani on thu...
# 4  swedish ready-to-assembl furnitur retail ikea ...

# %% [markdown]
# # 4)Define a function named lemmatize. It should accept some text and return the text after applying lemmatization to each word.

# %%
def lemmatize(string):
    
    wnl = nltk.stem.WordNetLemmatizer()
    
    lemmas = [wnl.lemmatize(word) for word in string.split()]
    
    lemmatized_string = ' '.join(lemmas)
    
    return lemmatized_string

# %%
business_df['lemmatize']=business_df['content'].apply(lemmatize)
business_df.head()
# Out:
#                                                title  \
# 0  Infosys' attrition drops to 27.1%, net employe...
# 1  We do not support dual employment: Infosys on ...
# 2  Musk sells $1 million worth of 'Burnt Hair' pe...
# 3  Mukesh Ambani visits Kedarnath & Badrinath shr...
# 4  IKEA lays off 10,000 employees after halting R...
#
#                                              content  category  \
# 0  Infosys on Thursday reported a 1.3% QoQ drop i...  business
# 1  Infosys CEO Salil Parekh spoke on the moonligh...  business
# 2  The world's richest person Elon Musk earned a ...  business
# 3  Reliance Industries Chairman Mukesh Ambani on ...  business
# 4  Swedish ready-to-assemble furniture retailer I...  business
#
#                                          basic_clean  \
# 0  infosys on thursday reported a 13 qoq drop in ...
# 1  infosys ceo salil parekh spoke on the moonligh...
# 2  the world's richest person elon musk earned a ...
# 3  reliance industries chairman mukesh ambani on ...
# 4  swedish readytoassemble furniture retailer ike...
#
#                                             tokenize  \
# 0  Infosys on Thursday reported a 1.3 % QoQ drop ...
# 1  Infosys CEO Salil Parekh spoke on the moonligh...
# 2  The world ' s richest person Elon Musk earned ...
# 3  Reliance Industries Chairman Mukesh Ambani on ...
# 4  Swedish ready-to-assemble furniture retailer I...
#
#                                                 stem  \
# 0  infosi on thursday report a 1.3% qoq drop in i...
# 1  infosi ceo salil parekh spoke on the moonlight...
# 2  the world' richest person elon musk earn a mil...
# 3  relianc industri chairman mukesh ambani on thu...
# 4  swedish ready-to-assembl furnitur retail ikea ...
#
#                                            lemmatize
# 0  Infosys on Thursday reported a 1.3% QoQ drop i...
# 1  Infosys CEO Salil Parekh spoke on the moonligh...
# 2  The world's richest person Elon Musk earned a ...
# 3  Reliance Industries Chairman Mukesh Ambani on ...
# 4  Swedish ready-to-assemble furniture retailer I...

# %% [markdown]
# # 5)Define a function named remove_stopwords. It should accept some text and return the text after removing all the stopwords.
#
# >This function should define two optional parameters, extra_words and exclude_words. These parameters should define any additional stop words to include, and any words that we don't want to remove.

# %%
def remove_stopwords(string, extra_words=None, exclude_words=None):
    
    stopword_list = stopwords.words('english')
    
    if exclude_words:
        
        stopword_list = stopword_list + exclude_words
        
    if extra_words:
        
        for word in extra_words:
            
            stopword_list.remove(word)
            
    words = string.split()
    
    filtered_words = [word for word in words if word not in stopword_list]
    
    filtered_string = ' '.join(filtered_words)
    
    return filtered_string

# %%
business_df['remove_stopwords'] = business_df['content'].apply(remove_stopwords)

business_df.head()
# Out:
#                                                title  \
# 0  Infosys' attrition drops to 27.1%, net employe...
# 1  We do not support dual employment: Infosys on ...
# 2  Musk sells $1 million worth of 'Burnt Hair' pe...
# 3  Mukesh Ambani visits Kedarnath & Badrinath shr...
# 4  IKEA lays off 10,000 employees after halting R...
#
#                                              content  category  \
# 0  Infosys on Thursday reported a 1.3% QoQ drop i...  business
# 1  Infosys CEO Salil Parekh spoke on the moonligh...  business
# 2  The world's richest person Elon Musk earned a ...  business
# 3  Reliance Industries Chairman Mukesh Ambani on ...  business
# 4  Swedish ready-to-assemble furniture retailer I...  business
#
#                                          basic_clean  \
# 0  infosys on thursday reported a 13 qoq drop in ...
# 1  infosys ceo salil parekh spoke on the moonligh...
# 2  the world's richest person elon musk earned a ...
# 3  reliance industries chairman mukesh ambani on ...
# 4  swedish readytoassemble furniture retailer ike...
#
#                                             tokenize  \
# 0  Infosys on Thursday reported a 1.3 % QoQ drop ...
# 1  Infosys CEO Salil Parekh spoke on the moonligh...
# 2  The world ' s richest person Elon Musk earned ...
# 3  Reliance Industries Chairman Mukesh Ambani on ...
# 4  Swedish ready-to-assemble furniture retailer I...
#
#                                                 stem  \
# 0  infosi on thursday report a 1.3% qoq drop in i...
# 1  infosi ceo salil parekh spoke on the moonlight...
# 2  the world' richest person elon musk earn a mil...
# 3  relianc industri chairman mukesh ambani on thu...
# 4  swedish ready-to-assembl furnitur retail ikea ...
#
#                                            lemmatize  \
# 0  Infosys on Thursday reported a 1.3% QoQ drop i...
# 1  Infosys CEO Salil Parekh spoke on the moonligh...
# 2  The world's richest person Elon Musk earned a ...
# 3  Reliance Industries Chairman Mukesh Ambani on ...
# 4  Swedish ready-to-assemble furniture retailer I...
#
#                                     remove_stopwords
# 0  Infosys Thursday reported 1.3% QoQ drop volunt...
# 1  Infosys CEO Salil Parekh spoke moonlighting de...
# 2  The world's richest person Elon Musk earned mi...
# 3  Reliance Industries Chairman Mukesh Ambani Thu...
# 4  Swedish ready-to-assemble furniture retailer I...

# %% [markdown]
# # 6)Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe news_df.

# %%
news_df= business_df_2
news_df.head()
# Out:
#                                                title  \
# 0  Infosys' attrition drops to 27.1%, net employe...
# 1  We do not support dual employment: Infosys on ...
# 2  Musk sells $1 million worth of 'Burnt Hair' pe...
# 3  Mukesh Ambani visits Kedarnath & Badrinath shr...
# 4  IKEA lays off 10,000 employees after halting R...
#
#                                              content  category
# 0  Infosys on Thursday reported a 1.3% QoQ drop i...  business
# 1  Infosys CEO Salil Parekh spoke on the moonligh...  business
# 2  The world's richest person Elon Musk earned a ...  business
# 3  Reliance Industries Chairman Mukesh Ambani on ...  business
# 4  Swedish ready-to-assemble furniture retailer I...  business

# %% [markdown]
# # 7)Make another dataframe for the Codeup blog posts. Name the dataframe codeup_df.

# %%
codeup_df=df
codeup_df.head()

# %% [markdown]
# # 8)For each dataframe, produce the following columns:
#
# >title to hold the title
#
# >original to hold the original article/post content
#
# >clean to hold the normalized and tokenized original with the stopwords removed.
#
# >stemmed to hold the stemmed version of the cleaned data.
#
# >lemmatized to hold the lemmatized version of the cleaned data.

# %%
codeup_df['clean'] = codeup_df['content'].apply(basic_clean).apply(tokenize).apply(remove_stopwords)
codeup_df['stemmed'] = codeup_df['content'].apply(stem)
codeup_df['lemmatize'] = codeup_df['content'].apply(lemmatize)
codeup_df.head()
# Out:
#                                                title date_published  \
# 0               Is a Career in Tech Recession-Proof?   Aug 12, 2022
# 1  Codeup Honored as SABJ Diversity and Inclusion...    Oct 7, 2022
# 2            How Can I Finance My Career Transition?   Sep 29, 2022
# 3          Tips for Women Beginning a Career in Tech   Sep 23, 2022
# 4   2022 SABJ C-Suite Award Winner: Stephen Noteboom    Sep 9, 2022
#
#                                              content  \
# 0  \n\n\n\n\n\nGiven the current economic climate...
# 1  \nCodeup has been named the 2022 Diversity and...
# 2  \nDeciding to transition into a tech career is...
# 3  \nCodeup strongly values diversity, and inclus...
# 4  \nCodeup’s Chief Operating Officer, Stephen No...
#
#                                                clean  \
# 0  given current economic climate many economists...
# 1  codeup named 2022 diversity inclusion award wi...
# 2  deciding transition tech career big step signi...
# 3  codeup strongly values diversity inclusion hon...
# 4  codeups chief operating officer stephen notebo...
#
#                                              stemmed  \
# 0  given the current econom climate, mani economi...
# 1  codeup ha been name the 2022 divers and inclus...
# 2  decid to transit into a tech career is a big s...
# 3  codeup strongli valu diversity, and inclusion....
# 4  codeup’ chief oper officer, stephen noteboom h...
#
#                                           lemmatized
# 0  Given the current economic climate, many econo...
# 1  Codeup ha been named the 2022 Diversity and In...
# 2  Deciding to transition into a tech career is a...
# 3  Codeup strongly value diversity, and inclusion...
# 4  Codeup’s Chief Operating Officer, Stephen Note...

# %%
news_df['clean'] = news_df['content'].apply(basic_clean).apply(tokenize).apply(remove_stopwords)
news_df['stemmed'] = news_df['content'].apply(stem)
news_df['lemmatize'] = news_df['content'].apply(lemmatize)
news_df.head()
# Out:
#                                                title  \
# 0  Infosys' attrition drops to 27.1%, net employe...
# 1  We do not support dual employment: Infosys on ...
# 2  Musk sells $1 million worth of 'Burnt Hair' pe...
# 3  Mukesh Ambani visits Kedarnath & Badrinath shr...
# 4  IKEA lays off 10,000 employees after halting R...
#
#                                              content  category  \
# 0  Infosys on Thursday reported a 1.3% QoQ drop i...  business
# 1  Infosys CEO Salil Parekh spoke on the moonligh...  business
# 2  The world's richest person Elon Musk earned a ...  business
# 3  Reliance Industries Chairman Mukesh Ambani on ...  business
# 4  Swedish ready-to-assemble furniture retailer I...  business
#
#                                                clean  \
# 0  infosys thursday reported 13 qoq drop voluntar...
# 1  infosys ceo salil parekh spoke moonlighting de...
# 2  world ' richest person elon musk earned millio...
# 3  reliance industries chairman mukesh ambani thu...
# 4  swedish readytoassemble furniture retailer ike...
#
#                                              stemmed  \
# 0  infosi on thursday report a 1.3% qoq drop in i...
# 1  infosi ceo salil parekh spoke on the moonlight...
# 2  the world' richest person elon musk earn a mil...
# 3  relianc industri chairman mukesh ambani on thu...
# 4  swedish ready-to-assembl furnitur retail ikea ...
#
#                                            lemmatize
# 0  Infosys on Thursday reported a 1.3% QoQ drop i...
# 1  Infosys CEO Salil Parekh spoke on the moonligh...
# 2  The world's richest person Elon Musk earned a ...
# 3  Reliance Industries Chairman Mukesh Ambani on ...
# 4  Swedish ready-to-assemble furniture retailer I...
